# %%
datapath = "data/recipes.txt"
with open (datapath, 'r') as f:
    # Read the file into a list
    recipes = []
    for line in f:
        line = line.strip()
        recipes.append(line)
    print(recipes)
# Out:
# ['Garlic Butter Mushrooms | Ingredients: mushrooms, garlic, butter, parsley, salt, black pepper', 'Creamy Coleslaw | Ingredients: cabbage, carrot, mayonnaise, vinegar, sugar, salt, pepper', 'Cilantro Lime Rice | Ingredients: rice, cilantro, lime juice, lime zest, salt', 'Maple Roasted Carrots | Ingredients: carrots, maple syrup, olive oil, salt, pepper', 'Parmesan Zucchini Fries | Ingredients: zucchini, parmesan cheese, eggs, salt, pepper', 'Cheesy Cauliflower Bake | Ingredients: cauliflower, cream cheese, cheddar cheese, garlic, salt, pepper', 'Spicy Sweet Potato Wedges | Ingredients: sweet potatoes, olive oil, chili powder, salt', 'Sautéed Green Beans | Ingredients: green beans, garlic, olive oil, salt, pepper', 'Caprese Salad Skewers | Ingredients: cherry tomatoes, mozzarella balls, balsamic vinegar, basil', 'Broccoli and Cheese Stuffed Potatoes | Ingredients: potatoes, broccoli, cheddar cheese, milk, salt, pepper', 'Corn and Black Bean Salad | Ingredients: corn kernels, black beans, lime juice, olive oil, salt, pepper', 'Balsamic Brussels Sprouts | Ingredients: Brussels sprouts, balsamic vinegar, honey, olive oil, salt, pepper', 'Stuffed Bell Peppers | Ingredients: bell peppers, rice, tomato, ground beef, garlic, cheese', 'Roasted Beet and Feta Salad | Ingredients: beets, feta cheese, olive oil, balsamic vinegar, salt, pepper', 'Greek Style Lemon Potatoes | Ingredients: potatoes, lemon juice, olive oil, garlic, oregano, salt, pepper', 'Spinach and Cheese Stuffed Mushrooms | Ingredients: mushrooms, spinach, cream cheese, garlic, salt, pepper', 'Herbed Couscous | Ingredients: couscous, chicken broth, lemon zest, parsley, salt', 'Cucumber Dill Salad | Ingredients: cucumber, dill, yogurt, garlic, lemon juice, salt, pepper', 'Quinoa Tabbouleh | Ingredients: quinoa, parsley, tomato, cucumber, lemon juice, olive oil, salt', 'Butternut Squash Soup | Ingredients: butternut squash, onion, garlic, chicken broth, cream, salt, pepper', 'Garlic Parmesan Asparagus | Ingredients: asparagus, parmesan cheese, garlic, olive oil, salt, pepper', 'Mashed Sweet Potatoes | Ingredients: sweet potatoes, butter, milk, cinnamon, salt', 'Sesame Ginger Bok Choy | Ingredients: bok choy, sesame oil, soy sauce, garlic, ginger, sesame seeds', 'Cheesy Polenta | Ingredients: polenta (cornmeal), chicken broth, cheddar cheese, butter, salt, pepper', 'Pesto Pasta Salad | Ingredients: pasta, pesto sauce, cherry tomatoes, parmesan cheese', 'Honey Glazed Baby Carrots | Ingredients: baby carrots, honey, butter, parsley, salt, pepper', 'Mediterranean Chickpea Salad | Ingredients: chickpeas, cucumber, tomato, onion, feta cheese, olive oil, lemon juice, parsley', 'Fried Green Tomatoes | Ingredients: green tomatoes, eggs, flour, milk, salt, pepper, vegetable oil', 'Crispy Onion Rings | Ingredients: onions, flour, eggs, milk, salt, pepper, vegetable oil', 'Apple Walnut Salad | Ingredients: mixed greens, apples, walnuts, blue cheese, vinegar, olive oil']

# %%
# create an empty dictionary to hold the index
recipe_index = {}

# go through the recipes
for recipe in recipes:

    # (the key(s) is/are: ingredients)
    # (the value(s) is/are: recipe names)
    # (parse out the keys and values you want to index from the item if necessary)
    
    # first let's split it into recipe name and list of ingredients
    recipe_name, ingredients = recipe.split(" | ")
    
    # WE NEED TO GET RID OF THE INGREDIENTS
    ingredients = ingredients.replace("Ingredients: ", "")

    # get each individual ingredient
    ingredient_list = ingredients.split(",")

    # now we can index each individual ingredient, which is our key
    for this_ingredient in ingredient_list:
    
        # GET the current value associated with the key in the index
        these_recipes = recipe_index.get(this_ingredient, [])
    
        # UPDATE the value
        these_recipes.append(recipe_name)
        
        # UPDATE the index with the key and its updated value
        recipe_index.update({this_ingredient: these_recipes})

recipe_index
# Out:
# {'mushrooms': ['Garlic Butter Mushrooms',
#   'Spinach and Cheese Stuffed Mushrooms'],
#  ' garlic': ['Garlic Butter Mushrooms',
#   'Cheesy Cauliflower Bake',
#   'Sautéed Green Beans',
#   'Stuffed Bell Peppers',
#   'Greek Style Lemon Potatoes',
#   'Spinach and Cheese Stuffed Mushrooms',
#   'Cucumber Dill Salad',
#   'Butternut Squash Soup',
#   'Garlic Parmesan Asparagus',
#   'Sesame Ginger Bok Choy'],
#  ' butter': ['Garlic Butter Mushrooms',
#   'Mashed Sweet Potatoes',
#   'Cheesy Polenta',
#   'Honey Glazed Baby Carrots'],
#  ' parsley': ['Garlic Butter Mushrooms',
#   'Herbed Couscous',
#   'Quinoa Tabbouleh',
#   'Honey Glazed Baby Carrots',
#   'Mediterranean Chickpea Salad'],
#  ' salt': ['Garlic Butter Mushrooms',
#   'Creamy Coleslaw',
#   'Cilantro Lime Rice',
#   'Maple Roasted Carrots',
#   'Parmesan Zucchini Fries',
#   'Cheesy Cauliflower Bake',
#   'Spicy Sweet Potato Wedges',
#   'Sautéed Green Beans',
#   'Broccoli and Cheese Stuffed Potatoes',
#   'Corn and Black Bean Salad',
#   'Balsamic Brussels Sprouts',
#   'Roasted Beet and Feta Salad',
#   'Greek Style Lemon Potatoes',
#   'Spinach and Cheese Stuffed Mushrooms',
#   'Herbed Couscous',
#   'Cucumber Dill Salad',
#   'Quinoa Tabbouleh',
#   'Butternut Squash Soup',
#   'Garlic Parmesan Asparagus',
#   'Mashed Sweet Potatoes',
#   'Cheesy Polenta',
#   'Honey Glazed Baby Carrots',
#   'Fried Green Tomatoes',
#   'Crispy Onion Rings'],
#  ' black pepper': ['Garlic Butter Mushrooms'],
#  'cabbage': ['Creamy Coleslaw'],
#  ' carrot': ['Creamy Coleslaw'],
#  ' mayonnaise': ['Creamy Coleslaw'],
#  ' vinegar': ['Creamy Coleslaw', 'Apple Walnut Salad'],
#  ' sugar': ['Creamy Coleslaw'],
#  ' pepper': ['Creamy Coleslaw',
#   'Maple Roasted Carrots',
#   'Parmesan Zucchini Fries',
#   'Cheesy Cauliflower Bake',
#   'Sautéed Green Beans',
#   'Broccoli and Cheese Stuffed Potatoes',
#   'Corn and Black Bean Salad',
#   'Balsamic Brussels Sprouts',
#   'Roasted Beet and Feta Salad',
#   'Greek Style Lemon Potatoes',
#   'Spinach and Cheese Stuffed Mushrooms',
#   'Cucumber Dill Salad',
#   'Butternut Squash Soup',
#   'Garlic Parmesan Asparagus',
#   'Cheesy Polenta',
#   'Honey Glazed Baby Carrots',
#   'Fried Green Tomatoes',
#   'Crispy Onion Rings'],
#  'rice': ['Cilantro Lime Rice'],
#  ' cilantro': ['Cilantro Lime Rice'],
#  ' lime juice': ['Cilantro Lime Rice', 'Corn and Black Bean Salad'],
#  ' lime zest': ['Cilantro Lime Rice'],
#  'carrots': ['Maple Roasted Carrots'],
#  ' maple syrup': ['Maple Roasted Carrots'],
#  ' olive oil': ['Maple Roasted Carrots',
#   'Spicy Sweet Potato Wedges',
#   'Sautéed Green Beans',
#   'Corn and Black Bean Salad',
#   'Balsamic Brussels Sprouts',
#   'Roasted Beet and Feta Salad',
#   'Greek Style Lemon Potatoes',
#   'Quinoa Tabbouleh',
#   'Garlic Parmesan Asparagus',
#   'Mediterranean Chickpea Salad',
#   'Apple Walnut Salad'],
#  'zucchini': ['Parmesan Zucchini Fries'],
#  ' parmesan cheese': ['Parmesan Zucchini Fries',
#   'Garlic Parmesan Asparagus',
#   'Pesto Pasta Salad'],
#  ' eggs': ['Parmesan Zucchini Fries',
#   'Fried Green Tomatoes',
#   'Crispy Onion Rings'],
#  'cauliflower': ['Cheesy Cauliflower Bake'],
#  ' cream cheese': ['Cheesy Cauliflower Bake',
#   'Spinach and Cheese Stuffed Mushrooms'],
#  ' cheddar cheese': ['Cheesy Cauliflower Bake',
#   'Broccoli and Cheese Stuffed Potatoes',
#   'Cheesy Polenta'],
#  'sweet potatoes': ['Spicy Sweet Potato Wedges', 'Mashed Sweet Potatoes'],
#  ' chili powder': ['Spicy Sweet Potato Wedges'],
#  'green beans': ['Sautéed Green Beans'],
#  'cherry tomatoes': ['Caprese Salad Skewers'],
#  ' mozzarella balls': ['Caprese Salad Skewers'],
#  ' balsamic vinegar': ['Caprese Salad Skewers',
#   'Balsamic Brussels Sprouts',
#   'Roasted Beet and Feta Salad'],
#  ' basil': ['Caprese Salad Skewers'],
#  'potatoes': ['Broccoli and Cheese Stuffed Potatoes',
#   'Greek Style Lemon Potatoes'],
#  ' broccoli': ['Broccoli and Cheese Stuffed Potatoes'],
#  ' milk': ['Broccoli and Cheese Stuffed Potatoes',
#   'Mashed Sweet Potatoes',
#   'Fried Green Tomatoes',
#   'Crispy Onion Rings'],
#  'corn kernels': ['Corn and Black Bean Salad'],
#  ' black beans': ['Corn and Black Bean Salad'],
#  'Brussels sprouts': ['Balsamic Brussels Sprouts'],
#  ' honey': ['Balsamic Brussels Sprouts', 'Honey Glazed Baby Carrots'],
#  'bell peppers': ['Stuffed Bell Peppers'],
#  ' rice': ['Stuffed Bell Peppers'],
#  ' tomato': ['Stuffed Bell Peppers',
#   'Quinoa Tabbouleh',
#   'Mediterranean Chickpea Salad'],
#  ' ground beef': ['Stuffed Bell Peppers'],
#  ' cheese': ['Stuffed Bell Peppers'],
#  'beets': ['Roasted Beet and Feta Salad'],
#  ' feta cheese': ['Roasted Beet and Feta Salad',
#   'Mediterranean Chickpea Salad'],
#  ' lemon juice': ['Greek Style Lemon Potatoes',
#   'Cucumber Dill Salad',
#   'Quinoa Tabbouleh',
#   'Mediterranean Chickpea Salad'],
#  ' oregano': ['Greek Style Lemon Potatoes'],
#  ' spinach': ['Spinach and Cheese Stuffed Mushrooms'],
#  'couscous': ['Herbed Couscous'],
#  ' chicken broth': ['Herbed Couscous',
#   'Butternut Squash Soup',
#   'Cheesy Polenta'],
#  ' lemon zest': ['Herbed Couscous'],
#  'cucumber': ['Cucumber Dill Salad'],
#  ' dill': ['Cucumber Dill Salad'],
#  ' yogurt': ['Cucumber Dill Salad'],
#  'quinoa': ['Quinoa Tabbouleh'],
#  ' cucumber': ['Quinoa Tabbouleh', 'Mediterranean Chickpea Salad'],
#  'butternut squash': ['Butternut Squash Soup'],
#  ' onion': ['Butternut Squash Soup', 'Mediterranean Chickpea Salad'],
#  ' cream': ['Butternut Squash Soup'],
#  'asparagus': ['Garlic Parmesan Asparagus'],
#  ' cinnamon': ['Mashed Sweet Potatoes'],
#  'bok choy': ['Sesame Ginger Bok Choy'],
#  ' sesame oil': ['Sesame Ginger Bok Choy'],
#  ' soy sauce': ['Sesame Ginger Bok Choy'],
#  ' ginger': ['Sesame Ginger Bok Choy'],
#  ' sesame seeds': ['Sesame Ginger Bok Choy'],
#  'polenta (cornmeal)': ['Cheesy Polenta'],
#  'pasta': ['Pesto Pasta Salad'],
#  ' pesto sauce': ['Pesto Pasta Salad'],
#  ' cherry tomatoes': ['Pesto Pasta Salad'],
#  'baby carrots': ['Honey Glazed Baby Carrots'],
#  'chickpeas': ['Mediterranean Chickpea Salad'],
#  'green tomatoes': ['Fried Green Tomatoes'],
#  ' flour': ['Fried Green Tomatoes', 'Crispy Onion Rings'],
#  ' vegetable oil': ['Fried Green Tomatoes', 'Crispy Onion Rings'],
#  'onions': ['Crispy Onion Rings'],
#  'mixed greens': ['Apple Walnut Salad'],
#  ' apples': ['Apple Walnut Salad'],
#  ' walnuts': ['Apple Walnut Salad'],
#  ' blue cheese': ['Apple Walnut Salad']}

# %%
import json
outputpath = "outputs/recipe-index.json"
with open(outputpath, "w") as f:
    f.write(json.dumps(recipe_index, indent=4))
